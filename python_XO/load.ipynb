# %%
from tensorflow.keras.models import load_model

model = load_model("tic_tac_toe_model.h5")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from tensorflow.keras.models import load_model
#       3 model = load_model("tic_tac_toe_model.h5")
#
# File c:\Users\hoker\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\__init__.py:47
#      44 from tensorflow.python import tf2 as _tf2
#      45 _tf2.enable()
# ---> 47 from tensorflow._api.v2 import __internal__
#      48 from tensorflow._api.v2 import __operators__
#      49 from tensorflow._api.v2 import audio
#
# File c:\Users\hoker\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:11
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
# ---> 11 from tensorflow._api.v2.__internal__ import distribute
# ...
